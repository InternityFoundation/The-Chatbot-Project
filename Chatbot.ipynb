# %%
import pandas as pd

# %%
conv_lines[0]
# Out:
# "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L194', 'L195', 'L196', 'L197']"

# %%
lines[0]
# Out:
# 'L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!'

# %%
movie_titles=open('movie_titles_metadata.txt',encoding='utf-8',errors='ignore').read().split('\n')

# %%
mt_data=[x.split('+++$+++') for x in movie_titles]

# %%
mt_data[0]
# Out:
# ['m0 ',
#  ' 10 things i hate about you ',
#  ' 1999 ',
#  ' 6.90 ',
#  ' 62847 ',
#  " ['comedy', 'romance']"]

# %%
movie_titles_=pd.DataFrame(mt_data)

# %%
movie_titles_.columns=['movie_id','title','year','rating','IMDB_votes','Genres']

# %%
movie_titles_
# Out:
#     movie_id                                            title      year  \
# 0        m0                       10 things i hate about you      1999
# 1        m1                       1492: conquest of paradise      1992
# 2        m2                                       15 minutes      2001
# 3        m3                            2001: a space odyssey      1968
# 4        m4                                          48 hrs.      1982
# 5        m5                                the fifth element      1997
# 6        m6                                              8mm      1999
# 7        m7    a nightmare on elm street 4: the dream master      1988
# 8        m8       a nightmare on elm street: the dream child      1989
# 9        m9                             the atomic submarine      1959
# 10      m10                                       affliction      1997
# 11      m11                                    air force one      1997
# ...

# %%
movie_chars=open('movie_characters_metadata.txt',encoding='utf-8',errors='ignore').read().split('\n')

# %%
movie_chars
# Out:
# ['u0 +++$+++ BIANCA +++$+++ m0 +++$+++ 10 things i hate about you +++$+++ f +++$+++ 4',
#  'u1 +++$+++ BRUCE +++$+++ m0 +++$+++ 10 things i hate about you +++$+++ ? +++$+++ ?',
#  'u2 +++$+++ CAMERON +++$+++ m0 +++$+++ 10 things i hate about you +++$+++ m +++$+++ 3',
#  'u3 +++$+++ CHASTITY +++$+++ m0 +++$+++ 10 things i hate about you +++$+++ ? +++$+++ ?',
#  'u4 +++$+++ JOEY +++$+++ m0 +++$+++ 10 things i hate about you +++$+++ m +++$+++ 6',
#  'u5 +++$+++ KAT +++$+++ m0 +++$+++ 10 things i hate about you +++$+++ f +++$+++ 2',
#  'u6 +++$+++ MANDELLA +++$+++ m0 +++$+++ 10 things i hate about you +++$+++ f +++$+++ 7',
#  'u7 +++$+++ MICHAEL +++$+++ m0 +++$+++ 10 things i hate about you +++$+++ m +++$+++ 5',
#  'u8 +++$+++ MISS PERKY +++$+++ m0 +++$+++ 10 things i hate about you +++$+++ ? +++$+++ ?',
#  'u9 +++$+++ PATRICK +++$+++ m0 +++$+++ 10 things i hate about you +++$+++ m +++$+++ 1',
#  'u10 +++$+++ SHARON +++$+++ m0 +++$+++ 10 things i hate about you +++$+++ ? +++$+++ ?',
# ...

# %%
mc_data=[x.split('+++$+++') for x in movie_chars]

# %%
mc_data
# Out:
# [['u0 ', ' BIANCA ', ' m0 ', ' 10 things i hate about you ', ' f ', ' 4'],
#  ['u1 ', ' BRUCE ', ' m0 ', ' 10 things i hate about you ', ' ? ', ' ?'],
#  ['u2 ', ' CAMERON ', ' m0 ', ' 10 things i hate about you ', ' m ', ' 3'],
#  ['u3 ', ' CHASTITY ', ' m0 ', ' 10 things i hate about you ', ' ? ', ' ?'],
#  ['u4 ', ' JOEY ', ' m0 ', ' 10 things i hate about you ', ' m ', ' 6'],
#  ['u5 ', ' KAT ', ' m0 ', ' 10 things i hate about you ', ' f ', ' 2'],
#  ['u6 ', ' MANDELLA ', ' m0 ', ' 10 things i hate about you ', ' f ', ' 7'],
#  ['u7 ', ' MICHAEL ', ' m0 ', ' 10 things i hate about you ', ' m ', ' 5'],
#  ['u8 ', ' MISS PERKY ', ' m0 ', ' 10 things i hate about you ', ' ? ', ' ?'],
#  ['u9 ', ' PATRICK ', ' m0 ', ' 10 things i hate about you ', ' m ', ' 1'],
#  ['u10 ', ' SHARON ', ' m0 ', ' 10 things i hate about you ', ' ? ', ' ?'],
#  ['u11 ', ' WALTER ', ' m0 ', ' 10 things i hate about you ', ' m ', ' 9'],
# ...

# %%
movie_chars_=pd.DataFrame(mc_data)

# %%
movie_chars_.columns=['characterID','character name','movieID','movie title','gender','credits']

# %%
movie_chars_.head()
# Out:
#   characterID character name movieID                   movie title gender  \
# 0         u0         BIANCA      m0    10 things i hate about you      f
# 1         u1          BRUCE      m0    10 things i hate about you      ?
# 2         u2        CAMERON      m0    10 things i hate about you      m
# 3         u3       CHASTITY      m0    10 things i hate about you      ?
# 4         u4           JOEY      m0    10 things i hate about you      m
#
#   credits
# 0       4
# 1       ?
# 2       3
# 3       ?
# 4       6

# %%
lines = open('movie_lines.txt', encoding='utf-8', errors='ignore').read().split('\n')

# %%
lines
# Out:
# ['L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!',
#  'L1044 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They do to!',
#  'L985 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I hope so.',
#  'L984 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She okay?',
#  "L925 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let's go.",
#  'L924 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Wow',
#  "L872 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Okay -- you're gonna need to learn how to lie.",
#  'L871 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No',
#  'L870 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?',
#  'L869 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like my fear of wearing pastels?',
#  'L868 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ The "real you".',
#  'L867 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ What good stuff?',
# ...

# %%
lines_data=[x.split('+++$+++') for x in lines]

# %%
lines_data
# Out:
# [['L1045 ', ' u0 ', ' m0 ', ' BIANCA ', ' They do not!'],
#  ['L1044 ', ' u2 ', ' m0 ', ' CAMERON ', ' They do to!'],
#  ['L985 ', ' u0 ', ' m0 ', ' BIANCA ', ' I hope so.'],
#  ['L984 ', ' u2 ', ' m0 ', ' CAMERON ', ' She okay?'],
#  ['L925 ', ' u0 ', ' m0 ', ' BIANCA ', " Let's go."],
#  ['L924 ', ' u2 ', ' m0 ', ' CAMERON ', ' Wow'],
#  ['L872 ',
#   ' u0 ',
#   ' m0 ',
#   ' BIANCA ',
#   " Okay -- you're gonna need to learn how to lie."],
#  ['L871 ', ' u2 ', ' m0 ', ' CAMERON ', ' No'],
#  ['L870 ',
#   ' u0 ',
#   ' m0 ',
#   ' BIANCA ',
#   ' I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?'],
#  ['L869 ', ' u0 ', ' m0 ', ' BIANCA ', ' Like my fear of wearing pastels?'],
#  ['L868 ', ' u2 ', ' m0 ', ' CAMERON ', ' The "real you".'],
#  ['L867 ', ' u0 ', ' m0 ', ' BIANCA ', ' What good stuff?'],
#  ['L866 ',
#   ' u2 ',
#   ' m0 ',
#   ' CAMERON ',
#   " I figured you'd get to the good stuff eventually."],
#  ['L865 ',
# ...

# %%
movie_lines_=pd.DataFrame(lines_data)

# %%
movie_lines_.columns=['lineID','characterID','movieID','character name','text of the utterance']

# %%
movie_lines_.head()
# Out:
#    lineID characterID movieID character name text of the utterance
# 0  L1045          u0      m0         BIANCA           They do not!
# 1  L1044          u2      m0        CAMERON            They do to!
# 2   L985          u0      m0         BIANCA             I hope so.
# 3   L984          u2      m0        CAMERON              She okay?
# 4   L925          u0      m0         BIANCA              Let's go.

# %%
conv_lines = open('movie_conversations.txt', encoding='utf-8', errors='ignore').read().split('\n')

# %%
conv_lines
# Out:
# ["u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L194', 'L195', 'L196', 'L197']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L198', 'L199']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L200', 'L201', 'L202', 'L203']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L204', 'L205', 'L206']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L207', 'L208']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L271', 'L272', 'L273', 'L274', 'L275']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L276', 'L277']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L280', 'L281']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L363', 'L364']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L365', 'L366']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L367', 'L368']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L401', 'L402', 'L403']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L404', 'L405', 'L406', 'L407']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L575', 'L576']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L577', 'L578']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L662', 'L663']",
# ...

# %%
conv_lines_data=[x.split('+++$+++') for x in conv_lines]

# %%
conv_movie_lines_=pd.DataFrame(conv_lines_data)

# %%
conv_movie_lines_.columns=['Char_id of 1st char','Char_id of 1st char','movie_id','occurances(has to be matched with movie_lines.txt)']

# %%
conv_movie_lines_.head()
# Out:
#   Char_id of 1st char Char_id of 1st char movie_id  \
# 0                 u0                  u2       m0
# 1                 u0                  u2       m0
# 2                 u0                  u2       m0
# 3                 u0                  u2       m0
# 4                 u0                  u2       m0
#
#   occurances(has to be matched with movie_lines.txt)
# 0                   ['L194', 'L195', 'L196', 'L197']
# 1                                   ['L198', 'L199']
# 2                   ['L200', 'L201', 'L202', 'L203']
# 3                           ['L204', 'L205', 'L206']
# 4                                   ['L207', 'L208']
